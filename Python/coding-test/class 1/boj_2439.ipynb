# %%
# 2439

n = int(input())
for i in range(1, n+1):
  print(' '*(n-i) + '*'*i)

# print 안에 쉼표(,)를 넘으면 자동으로 두개 사이에 공백이 생김
# -> + 를 사용하면 공백없이 두변수가 붙어서 출력됨
# Out:
# 5
#     *
#    **
#   ***
#  ****
# *****
